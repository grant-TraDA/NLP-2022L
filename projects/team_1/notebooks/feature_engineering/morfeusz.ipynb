# %%
# Morphosyntactic marker system (IPI PAN):
# http://nlp.ipipan.waw.pl/CORPUS/znakowanie.pdf
# http://nkjp.pl/poliqarp/help/plse2.html

# %%
import numpy as np
import pandas as pd

import morfeusz2
from IPython.display import display, Markdown

# %%
def filter_empty_strings(str_list):
    return list(filter(None, str_list))

def index_items(str_list):
    indices = []
    for i in range(len(str_list)):
        indices.append(i)
    return indices

def get_list_item(str_list, item_idx):
    return str_list[item_idx]

# %%
data_train_exp = pd.read_csv("../../data/outputs/feature_engineering/train/expected.csv")

# %%
base_items_df = data_train_exp.copy()
base_items_df["text_split"] = base_items_df["FixedOutput"].apply(str.split)
base_items_df["text_split"] = base_items_df["text_split"].apply(filter_empty_strings)
base_items_df["item_index"] = base_items_df["text_split"].apply(index_items)
base_items_df = base_items_df.explode("item_index").reset_index(drop=True)
base_items_df["item"] = base_items_df.apply(
    lambda x: get_list_item(x.text_split, x.item_index), axis=1
)

# %%
base_items_df
# Out:
#                 FileId                                        FixedOutput  \
# 0       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 1       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 2       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 3       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 4       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# ...                ...                                                ...
# 184458  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184459  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184460  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184461  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184462  wikinews195323  29 lutego na wydziale matematyki i informatyki...
#
#                                                text_split item_index  \
# 0       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          0
# 1       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          1
# 2       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          2
# 3       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          3
# 4       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          4
# ...                                                   ...        ...
# 184458  [29, lutego, na, wydziale, matematyki, i, info...        179
# 184459  [29, lutego, na, wydziale, matematyki, i, info...        180
# 184460  [29, lutego, na, wydziale, matematyki, i, info...        181
# 184461  [29, lutego, na, wydziale, matematyki, i, info...        182
# 184462  [29, lutego, na, wydziale, matematyki, i, info...        183
#
#              item
# 0               w
# 1       wywiadzie
# 2             dla
# 3          polski
# 4        jarosław
# ...           ...
# 184458    chopina
# 184459         30
# 184460      wstęp
# 184461      wolny
# 184462          .
#
# [184463 rows x 5 columns]

# %% [markdown]
# ### Adding columns with preceding and following words

# %%
prev_items_df = base_items_df.merge(
    base_items_df[["item_index", "item"]]
    .shift(1)
    .rename({"item": "prev_item", "item_index": "prev_item_index"}, axis=1),
    left_index=True,
    right_index=True,
)

items_df = prev_items_df.merge(
    base_items_df[["item_index", "item"]]
    .shift(-1)
    .rename({"item": "next_item", "item_index": "next_item_index"}, axis=1),
    left_index=True,
    right_index=True,
)

prev_cond_mask = items_df["item_index"] == 0
next_cond_mask = items_df["next_item_index"] == 0

items_df.loc[prev_cond_mask, "prev_item"] = np.nan
items_df.loc[next_cond_mask, "next_item"] = np.nan

items_df = items_df.drop(["prev_item_index", "next_item_index", "text_split"], axis=1)

# %%
items_df
# Out:
#                 FileId                                        FixedOutput  \
# 0       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 1       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 2       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 3       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 4       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# ...                ...                                                ...
# 184458  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184459  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184460  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184461  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184462  wikinews195323  29 lutego na wydziale matematyki i informatyki...
#
#        item_index       item  prev_item  next_item
# 0               0          w        NaN  wywiadzie
# 1               1  wywiadzie          w        dla
# 2               2        dla  wywiadzie     polski
# 3               3     polski        dla   jarosław
# 4               4   jarosław     polski  kaczyński
# ...           ...        ...        ...        ...
# 184458        179    chopina          .         30
# 184459        180         30    chopina      wstęp
# 184460        181      wstęp         30      wolny
# 184461        182      wolny      wstęp          .
# 184462        183          .      wolny        NaN
#
# [184463 rows x 6 columns]

# %% [markdown]
# ### Morphological analysis application

# %%
morf = morfeusz2.Morfeusz(analyse=True, generate=False, expand_tags=False)

morf_df = items_df[["item"]].copy()
morf_df["morf_analysis"] = morf_df["item"].apply(morf.analyse)

# %%
# extracting relevant information from the output
morf_df = morf_df.explode("morf_analysis").reset_index(drop=True)
morf_df['morf_analysis'] = morf_df['morf_analysis'].str[2]
morf_df["tag"] = morf_df['morf_analysis'].str[2]
morf_df = morf_df.drop('morf_analysis', axis=1)

# %%
morf_df
# Out:
#              item                          tag
# 0               w                prep:acc:nwok
# 1               w                prep:loc:nwok
# 2       wywiadzie              subst:sg:loc:m3
# 3       wywiadzie              subst:sg:voc:m3
# 4             dla                     prep:gen
# ...           ...                          ...
# 374641      wolny            adj:sg:acc:m3:pos
# 374642      wolny  adj:sg:nom.voc:m1.m2.m3:pos
# 374643      wolny            adj:sg:acc:m3:pos
# 374644      wolny  adj:sg:nom.voc:m1.m2.m3:pos
# 374645          .                       interp
#
# [374646 rows x 2 columns]

# %%
# checking the words unrecognized by Morpheusz2 (verification whether data cleaning process was correct)
df = morf_df.copy()
ignored_items = df.loc[df["tag"] == "ign"]["item"].value_counts()

for item in ignored_items.index:
    print(item)

ignored_items_df = ignored_items.reset_index().rename(
    {"item": "count", "index": "word"}, axis=1
)
ignored_items_df.to_csv(
    "../../data/outputs/feature_engineering/ignored_items_df.csv", index=False
)

# drop unrecognized items (listed below)
df = df.loc[df["tag"] != "ign"]
# Out:
# r
# np
# the
# godz
# of
# św
# tzw
# ks
# wikimedia
# moze
# prof
# itp
# fukushima
# tvn24
# itd
# n
# wikinews
# world
# commons
# f
# byc
# directx
# jesli
# obama
# displaystyle
# skype
# times
# gadu
# sagi2007
# good
# esa
# prosze
# sts
# tj
# ktos
# wst
# creative
# barroso
# wikipedystów
# mozna
# cos
# il
# nauru
# plusfon
# cov
# live
# ćwiąkalski
# ubuntu
# festival
# psp
# or
# porak
# bylo
# xx236
# play
# mark
# firefoksa
# jpg
# server
# whatever
# marienthal
# fernando
# etc
# lorber
# eric
# płd
# pirx
# byla
# avm
# lgbt
# bros
# an
# stage
# trappist
# miedwiediew
# jeff
# phoenix
# wiklol
# delaya
# orange
# guardian
# pologne
# dzong
# csc
# royal
# kastoreum
# starowce
# gazprom
# byl
# ency
# gg
# solidarnosc
# barack
# gazieta
# ditalia
# network
# chris
# newsweek
# lng
# przeciez
# troche
# menezesa
# borewicz
# albertus
# onet
# maest
# sdpl
# domo
# kashechkin
# niz
# alonso
# life
# andrew
# eu
# waziristanie
# dw
# mohammad
# canal
# googlea
# abu
# wz
# wikipedyści
# symantec
# roo72
# oczywiscie
# płn
# blackfish
# ww
# alessandro
# zwiazku
# milingo
# kaufland
# wikiprojekt
# church
# netii
# pd
# petacchi
# prow
# sun
# dlr
# daiichi
# ns
# cantoro
# duuuzo
# dolaczyc
# skrzydlami
# joymaster
# łoł
# bystoel
# rozwijac
# verfolgung
# occurrence
# zentrum
# btpk
# drosophila
# telecoms
# schetynę
# vulcanologia
# vigilium
# tarbunka
# hesja
# ffmalan
# sophie
# wuxi
# aol
# sereną
# pawmakprzydałoby
# tąd
# istilidion
# grandmont
# komentaz
# ksymil
# slyszalna
# brancion
# lc1
# reprezentancja
# dragonegg
# slavka
# zę
# stewart
# beit
# 0v
# rownież
# dictionary
# penas
# abdullah
# piastu
# materazzi
# najpojemnijeszych
# guard
# mesajah
# advanced
# jurgita
# ditlenku
# evgeni
# żomart
# evan
# partnership
# czakwetadze
# jboss
# damjana
# iłowajsku
# jasra
# ptrtlr
# porządkowedefinicja
# gomes
# rjtskądrze
# pouto
# fiorentiny
# champions
# carrefour
# warsiawy
# mapping
# uzsadnienie
# jakow
# cemil
# peszawarze
# cahill
# monbat
# bhutan
# credential
# galati
# negroponte
# wygladaja
# korkoneas
# funkcjonowac
# siałababamak
# ajmro
# ryst
# foxmana
# vadis
# broniaca
# mundry
# prawdopobnego
# galaxy
# mzopw
# dioxide
# napisałes
# litzmanna
# rft
# bibliography
# margah
# zapisalem
# lezy
# versus
# guang
# floss
# glupio
# c64
# neuronaukę
# polsich
# wlasnego
# randstad
# dyskusjateż
# cerkwii
# iitate
# salih
# zastapiony
# odmowic
# auxois
# latwe
# gajadhur
# ippoldt
# kilinoczi
# oldham
# sformulowanie
# socjolingwistyczne
# qblika
# dannenbergu
# hpi
# lander
# h0
# dsl
# mahmeda
# babacan
# qing
# lichtensteinu
# woo
# wyłonionoby
# międzynarosowej
# kyokushin
# winokurow
# ślazak
# radoniewicza
# yakhub
# henri
# konstatncinie
# credit
# lets
# tomq
# klopotu
# jwk
# reprezentatnów
# vaidisova
# tomonaga
# dogz
# meiji
# hrasnova
# clijsters
# netię
# czekac
# nuevo
# prittwitz
# nm
# ecotech
# allessandro
# zepsol
# lars
# stallings
# mazzoleniemu
# zremiksowanego
# egzekwo
# wyrózniła
# foxmanowi
# ghiringhelli
# grosjean
# mykiel
# antal
# bosniaks
# kasym
# vidliczka
# della
# bł
# administration
# iotrus
# paterm
# shabelleh
# hartson
# judi
# miteb
# agricole
# cold
# saudi
# powyzej
# deutschland
# celsiusza
# 230v
# wikireporter
# nelfort
# chetnie
# wikireportera
# klikne
# bettiniego
# raikkonenem
# f140
# produces
# pride
# finding
# espinal
# st45
# akselroda
# serapisa
# hautamaeki
# sebastien
# koksal
# polonizowac
# nedlugim
# hyper
# snchez
# alexandra
# remiksowania
# wykorzystalem
# kovacevic
# pierwiasta
# yasuyuki
# modeselektor
# tedxpoznań
# arbeit
# opieralo
# thai
# stenebo
# tapio
# zarkawiego
# wasiliew
# szweczenko
# torró
# swiata
# mohylek
# roels
# petrovowi
# zyd
# geimer
# genoa
# mlodziezowka
# dawan
# g6
# wfpc2
# vettel
# musica
# finnair
# rolando
# massimino
# hasel
# pirelli
# gerais
# nalezalo
# wax
# morera
# charlize
# inf
# dick
# welte
# shortise
# specific
# luco
# didżala
# mówia
# filmow
# copyrightr
# nightly
# joigny
# schlierenzauer
# nordberg
# security
# myslę
# selso
# hryniszak
# talewicz
# bruni
# southern
# eitan
# korean
# znikna
# uzywa
# granvorka
# ytek
# rzeczniczych
# clos
# sinan
# grzexsjak
# xt
# female
# cyclingu
# ophiophagus
# foursquare
# visones
# morrel
# yoandri
# scholl
# dambrosio
# marcin862
# rossi
# społecznikkandydatura
# deep
# frantz
# wyroznione
# erastianizmie
# minutes
# parafrazowo
# nossig
# theobalda
# booker
# think
# yildirim
# jogischesem
# morelon
# australoidzi
# advocate
# martinbutton
# gentelman
# lockheed
# bonaszewski
# hiuppo
# wzrastajacej
# khaleda
# huffman
# rasowo3
# jaimego
# knack
# joy
# transformatorowo
# miala
# llvm
# mastroeni
# sygn
# hello
# lichtensteinie
# tymbardziej
# 10yearsofrhel
# więcj
# flasha
# gierasimienko
# zasugerowal
# okreslonej
# verdugo
# furthermore
# khalifa
# sanzem
# forak
# chafik
# buttona
# bresciano
# doubs
# wytnięte
# kaukazoidzi
# polkomtela
# founder
# taaak
# isokratesa
# miesiace
# ę
# nimeców
# veuilly
# stworzyc
# mtm
# zur
# gasparotto
# gromit
# szah
# brosenspv
# podcasterów
# km3
# blackout
# infrared
# ocalil
# mooryc
# aleph
# dawkins
# voigtovi
# gp
# 1914r
# elfhelma
# larchi
# fesco
# szachar
# khel
# ekologiczno
# neurodynamikę
# odelvis
# dochnala
# negawe
# wirtualizacyjnego
# wlk
# poke
# odległościpodczas
# petković
# rudoportu
# mędralową
# ściągnąc
# wrs
# totschnig
# transseksulnych
# schwarzschlida
# nikoku
# smooth
# lasalle
# rickardsson
# hadley
# niculescu
# hui
# webber
# shin
# fawn
# roh
# drdc
# stepan
# belacqua
# kilwaterbordzista
# mielibyscie
# sirelius
# pysiekm
# yancheng
# republicain
# asif
# toptan
# channel
# winokurowa
# patrzac
# bluerandy
# scotland
# dostep
# atysta
# vth
# mółgbym
# armancon
# larsa
# bordaczow
# flies
# mbabane
# andybrandt
# małachowiance
# chrisem
# luigiego
# widomo
# keplera
# spadafora
# siewicz
# zobaczyc
# musurana
# ciolek
# thadden
# romani
# wilczebłota
# belushi
# odroznienia
# suzhou
# disambiguation
# marencjaodmianę
# speaking
# poppingiem
# kukz15
# mrągu
# einar
# raisi
# carrie
# emic
# león
# zawierac
# dirextx
# perrotta
# baracka
# yalea
# okladki
# cotterets
# henryego
# kilwaterbording
# dude
# osaadzić
# anchorage
# olli
# maclachlana
# ciurlok
# skaly
# robbentrop
# byung
# swpawel
# hamida
# grosjeanem
# saud
# mackay
# mlodziezowki
# battle
# gasperonim
# corriere
# moskowskije
# shimbun
# pajączy
# rozwinałem
# podraanin
# lampard
# zrezygnaować
# nowobudowanej
# sistema
# condor
# lipszyc
# juszczenki
# bartekchom
# frieddrichshafen
# itar
# vitalic
# zformułowane
# mysli
# soulscythe
# ammann
# asl
# suv
# blogoslawionych
# heidler
# shalali
# malouda
# podyskutujmyhasło
# zawodnikow
# sipisova
# polapie
# wikię
# seb
# dmitrijew
# heronim
# asab
# that
# prabhakaran
# warmiacy
# ugarit
# eichendorffa
# zaporożscy
# borja
# zarja
# uniw
# osmedia
# rowniez
# win95
# frei
# cnes
# latex
# dench
# maxymiliana
# deco
# ladem
# schnberg
# trentino
# blut
# hazzard
# ganascia
# qpczikw
# vinciego
# kurpiowskia
# arbela
# alehandroporaygmail
# cortony
# academy
# pokemonów
# studies
# majaca
# jimmiego
# wide
# gynandromorphs
# viral
# ehuda
# pimentel
# bl
# wos
# szczególy
# zoll
# mauna
# zakopower
# mysql
# dyskietkowe
# wikilinków
# bowe
# verheugena
# vakifgunesttelekom
# puglia
# mozesz
# backendu
# indrzejczyka
# donesienia
# kazdego
# częsciej
# isntieje
# kemyd
# andriejewa
# bourg
# asseco
# sadosia
# tsang
# hiun
# zigić
# tylera
# westerwelle
# kliknalem
# milosz
# teologtak
# pistons
# istniec
# hushovd
# poczodzi
# gsl
# jericho
# frattini
# wiciszenie
# surveyor
# myśliwieckiej
# zdjeciem
# authority
# wikiprojektem
# nigara
# curveball
# revenue
# zmpg
# food
# aniol
# stokczy
# bajaur
# 90tych
# ppc
# supramolekularnej
# najwczesniejsza
# takaaki
# byol
# quo
# moratinos
# isaf
# lger
# gupie
# podpisal
# nalezało
# sendai
# ptc
# gillon
# uśmierzaczy
# mayflower
# siltala
# neilla
# compostela
# sat
# filmaster
# liam
# samipałatyńsku
# ketlinga
# grohmana
# frances
# lgbtqia
# malaheedh
# volum
# bijuu
# openshift
# arthus
# kautzkich
# migatu
# home
# emmmm
# przyeszedł
# rodrguez
# peochar
# ziemianstwo
# delitzsch
# instead
# lomzynskiego
# moncych
# velupillai
# tokajew
# skangur
# antiqua
# użyszkodników
# kreske
# muhammad
# zdjęciamimario58
# co2
# krabik
# perić
# klementyńskiej
# used
# branislav
# prmoeniowania
# lapacz
# warhammer
# rozważalem
# nortomu
# niginie
# dave
# musharraf
# tramwaji
# artykulacy
# musaba
# kenwyne
# starscream
# emkaffe
# kilkudzisięciu
# saporta
# opendns
# googl
# mwalimu
# fwioo
# ledger
# abbas
# ledesma
# wulfstan
# 0x1ffb23p
# environment
# lwb
# podejsc
# spowrotem
# kuniszewicz
# maelstrom
# kashechkina
# epitestosteronu
# mazovii
# dynatek
# phipps
# protokananejski
# hs
# dodtkowo
# przegladaja
# bisauu
# qatar
# fonobaru
# tpsa
# games
# walks
# barratt
# seck
# colea
# rekacji
# kirsten
# rosajakie
# wzbogazenie
# ipku
# tallis
# rownowaznych
# ivica
# guus
# wedycji
# jonathan
# hack
# motif
# kangasniemi
# sauber
# estrack
# kyung
# nawaf
# waclawdzieciol
# 1017bq
# mlodziezowej
# niedociąnięć
# cicek
# calli
# oppama
# seitz
# pieniążny
# nazionale
# cloud
# brescia
# islamsy
# does
# rangunie
# noelia
# obruci
# sung
# glazunowa
# bosnians
# branimir
# lgplv2
# jorge
# wim
# caib
# podniu
# evo
# mattiego
# drum
# kpt
# pepenadores
# kollektiv
# sprick
# któej
# juha
# lorbera
# whitley
# industry
# ecw
# mezo
# dygitalizacja
# bernucci
# ilamu
# sarkozyego
# darmstadt
# klopot
# pzl
# ieee
# kaliniczenki
# portable
# teli
# ejski
# oesowych
# ses
# rather
# lewisa
# wilhousky
# kadlik
# explicatio
# yaradua
# biasutti
# guilliem
# porownujac
# bautista
# ie
# vise
# theatre
# cracker
# samantha
# now
# african
# hasty
# szebabami
# hostowaną
# cieżko
# palese
# praktyczcie
# bih
# sanbi
# resident
# aseksualizmem
# quick
# athar
# freeware
# encje
# quarkowym
# agency
# networkmanager
# znalezc
# 200x
# zbędy
# 1883r
# semi
# jiu
# bombs
# large
# gminoruchów
# szytenchelm
# jirsak
# grabiszyńska
# pslv
# masters
# nakamura
# backstoppers
# udoskonalic
# lo281
# wonsan
# mowic
# lahore
# styli
# terry
# p150
# wikireporterów
# zalegalizownaiu
# electronic
# piracy
# bedac
# novatora
# dyskusjaniestety
# peer
# dexter
# leenockiem
# publica
# kapstel
# frode
# zwirtualizowanych
# pgb
# włochywłoskie
# pisu
# spoloszczanie
# schneiderhahna
# kaplan
# wrzesnia
# yochanan
# czuriumow
# wielośc
# beijing
# hawkey
# obrazen
# thoku
# sacharę
# tedxkraków
# duhuk
# fawzi
# slowo
# zakaria
# jurquin
# australian
# hartinga
# abdirahman
# artu
# zaczeła
# hostuje
# robbie
# bsd
# chymm
# mingorę
# planete
# xbox
# op
# mcgaw
# megan
# szewacha
# róznorodnosc
# mówie
# boston9
# jaber
# glueck
# sbop
# kaszkawal
# schlieriego
# audioriver
# rębiewski
# mieszkancow
# whether
# lotusa
# contact
# oniros
# kinyongo
# szkolno
# zysmana
# pudelsi
# plobsheim
# artykol
# josef
# fsc
# gehsperre
# fashioner
# sultana
# randiego
# breezy
# bocanegrą
# kurówką
# zbedny
# ząbowy
# zachodznich
# lake
# ari
# motifa
# mons
# maps
# baraka
# zmarl
# należaloby
# topolanek
# punktow
# kuzniecowa
# haggis
# brou
# charente
# gerolsteiner
# canonical
# fizykaa
# valencii
# liscie
# independently
# adolescents
# eibin
# invest
# eichendorff
# zejda
# aerospace
# galerieji
# jezdzily
# upu
# stavrosa
# wtm
# beuthen
# srumień
# marcello
# lege
# bien
# termini
# giampaolo
# kkic
# jrs
# sadrija
# rijad
# jeremias
# guttierez
# wiktorynkażdy
# kyprianou
# more
# hippolyte
# mowi
# robby
# hoax
# helmand
# decade
# timeu
# panzerbuchse
# eit
# lodzermensch
# barybar19
# punjabie
# atomenergoprojekt
# poors
# guy
# bohosiewicz
# marako
# traktowac
# kori
# american
# stack
# hasama
# gardner
# abdalla
# overdose
# nss
# noora
# pge
# kyuubim
# encodes
# carrieego
# franaise
# dyskusjaoczy
# act
# mecgera
# usgs
# kinsey
# as532
# valentine
# rikknenowi
# cybiny
# tamazight
# norcia
# oesu
# wrzesniu
# lubrańskiego
# angieslkich
# andrejs
# systemd
# acting
# pakuzujących
# buy
# badri
# raczynska
# blizzconie
# daroooo
# umsyłów
# schaeublem
# mladen
# serwius
# vistą
# tendecyjny
# grande
# common
# pistulka
# luxtorpedą
# katrinę
# sajed
# żłobkowo
# adobe
# shideye
# rusol
# haguenau
# kosuke
# opp
# tsf
# zszedl
# wipurw
# ascher
# tartaru
# wyrazenie
# willens
# awesome
# winokourow
# adamat
# hoesjna
# clooney
# dyskusja12
# alouette
# wikipedystki
# bojović
# shaha

# %%
# checking the punctuation marks recognized by Morpheusz2
df.loc[df["tag"]=="interp"]["item"].value_counts()
# Out:
# .    10372
# ,    10069
# -     2422
# :      897
# ?      768
# !      114
# Name: item, dtype: int64

# %%
tmp = df['tag'].str.split(':', 1, expand=True).rename(
    {0: 'grammatical_class', 1:'grammatical_categories'},
    axis=1
    )

whitelist=['nom','gen','dat','acc','inst','loc','voc','imperf','perf']
pat = r'\b(?:{})\b'.format('|'.join(whitelist))
tmp['grammatical_categories']= tmp['grammatical_categories'].str.findall('(' + pat + ')').str.join('.')
df = pd.concat([df, tmp], axis=1)

# %%
df
# Out:
#              item                          tag grammatical_class  \
# 0               w                prep:acc:nwok              prep
# 1               w                prep:loc:nwok              prep
# 2       wywiadzie              subst:sg:loc:m3             subst
# 3       wywiadzie              subst:sg:voc:m3             subst
# 4             dla                     prep:gen              prep
# ...           ...                          ...               ...
# 374641      wolny            adj:sg:acc:m3:pos               adj
# 374642      wolny  adj:sg:nom.voc:m1.m2.m3:pos               adj
# 374643      wolny            adj:sg:acc:m3:pos               adj
# 374644      wolny  adj:sg:nom.voc:m1.m2.m3:pos               adj
# 374645          .                       interp            interp
#
#        grammatical_categories
# 0                         acc
# 1                         loc
# 2                         loc
# 3                         voc
# 4                         gen
# ...                       ...
# 374641                    acc
# 374642                nom.voc
# 374643                    acc
# 374644                nom.voc
# 374645                   None
#
# [367377 rows x 4 columns]

# %%
grammatical_categories_dict = (
    df.drop_duplicates(subset=["item", "grammatical_class"])
    .sort_values(["item", "grammatical_class"], ascending=True)
    .groupby(["item"])["grammatical_class"]
    .apply(";".join)
    .reset_index()
)

# %%
grammatical_categories_dict
# Out:
#            item grammatical_class
# 0             !            interp
# 1             ,            interp
# 2             -            interp
# 3             .            interp
# 4             0               dig
# ...         ...               ...
# 31268   żądanie         ger;subst
# 31269  żądaniem         ger;subst
# 31270     żądać               inf
# 31271     żądał             praet
# 31272     żądań         ger;subst
#
# [31273 rows x 2 columns]

# %% [markdown]
# ### Concatenate enriched frame with morphological analysis results

# %%
res_df = items_df.merge(grammatical_categories_dict, on="item", how="left").rename(
    {"grammatical_class": "item_classes"}, axis=1
)
res_df = res_df.merge(
    grammatical_categories_dict, left_on="prev_item", right_on="item", how="left"
).rename({"grammatical_class": "prev_item_classes"}, axis=1)
res_df = res_df.merge(
    grammatical_categories_dict, left_on="next_item", right_on="item", how="left"
).rename({"grammatical_class": "next_item_classes"}, axis=1)
res_df = res_df.drop(["item", "item_y"], axis=1).rename({"item_x": "item"}, axis=1)

# %% [markdown]
# ### Check the morphological environment of punctuation marks

# %%
punctuations_df = res_df.loc[res_df["item_classes"] == "interp"].reset_index()
punctuations_df = punctuations_df[
    [
        "FileId",
        "FixedOutput",
        "item",
        "prev_item",
        "prev_item_classes",
        "next_item",
        "next_item_classes",
    ]
]

punctuations_df
# Out:
#                FileId                                        FixedOutput item  \
# 0      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# 1      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    .
# 2      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# 3      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    -
# 4      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# ...               ...                                                ...  ...
# 24637  wikinews195323  29 lutego na wydziale matematyki i informatyki...    ,
# 24638  wikinews195323  29 lutego na wydziale matematyki i informatyki...    ,
# 24639  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
# 24640  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
# 24641  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
#
#               prev_item prev_item_classes         next_item  \
# 0            podkreślił             praet                że
# 1               państwa             subst                to
# 2              wszystko     adj;adv;subst                co
# 3            powiedzieć               inf      odpowiedział
# 4          odpowiedział             praet               gdy
# ...                 ...               ...               ...
# 24637     społecznością             subst  administrowaniem
# 24638  administrowaniem               ger               jak
# 24639       wikipediami             subst            wykład
# 24640                ul             subst           chopina
# 24641             wolny         adj;subst               NaN
#
#               next_item_classes
# 0                     comp;part
# 1      adj;comp;part;pred;subst
# 2          comp;part;prep;subst
# 3                         praet
# 4                      adv;comp
# ...                         ...
# 24637                       ger
# 24638  adv;comp;conj;prep;subst
# 24639                     subst
# 24640                     subst
# 24641                       NaN
#
# [24642 rows x 7 columns]

# %%
# re-check the target classes balance
punctuations_df["item"].value_counts()
# Out:
# .    10372
# ,    10069
# -     2422
# :      897
# ?      768
# !      114
# Name: item, dtype: int64

# %%
target_classes = [',', '.', '-', ':', '?', '!']

# %%
# check the items preceeding individual punctuation marks
res_dict = {}
for punct_symb in target_classes:
    display(Markdown(f'#### Punctuation mark: "{punct_symb}"'))
    df = punctuations_df.loc[punctuations_df["item"] == punct_symb].reset_index()
    display(pd.DataFrame(df["prev_item"].value_counts()).head(20))
# Out:
# #### Punctuation mark: ","
#               prev_item
# się                  91
# to                   74
# tym                  59
# powiedział           56
# roku                 54
# 1                    40
# osób                 38
# tego                 32
# 2                    31
# również              31
# dodał                31
# tak                  30
# polski               27
# stwierdził           26
# uważa                24
# zapowiedział         22
# osoby                22
# wynika               21
# nadzieję             21
# także                21
# #### Punctuation mark: "."
#         prev_item
# m             151
# r             135
# in            129
# roku          108
# ok             90
# np             66
# tys            63
# osób           55
# ul             48
# godz           46
# ds             43
# proc           37
# lat            37
# polski         29
# kraju          25
# św             24
# tzw            24
# pracy          24
# ks             24
# w              21
# #### Punctuation mark: "-"
#             prev_item
# al                 33
# polsko             21
# 2                  15
# 0                  12
# pis                12
# roku               12
# e                  11
# północno           10
# sts                10
# polski              9
# covid               9
# 4                   9
# sars                8
# południowo          8
# 30                  8
# biało               7
# 1                   7
# kujawsko            7
# 21                  7
# sms                 7
# #### Punctuation mark: ":"
#             prev_item
# wikipedia          22
# 20                 17
# 3                  15
# 16                 14
# 18                 14
# zgłasza            14
# 15                 13
# 13                 12
# 1                  12
# się                 9
# 12                  9
# 10                  9
# 17                  8
# in                  8
# 14                  8
# 11                  8
# to                  8
# 19                  8
# 2                   8
# powiedział          7
# #### Punctuation mark: "?"
#            prev_item
# nie                9
# chodzi             7
# artykule           6
# źródła             5
# było               5
# co                 5
# zaciekle           4
# błąd               4
# prawda             4
# dlaczego           4
# to                 4
# rzeszy             3
# źródło             3
# roku               3
# artykułów          3
# nazwa              3
# nazwy              3
# napisać            3
# polski             3
# żart               3
# #### Punctuation mark: "!"
#                   prev_item
# pozdrawiam                5
# się                       4
# konta                     4
# witam                     3
# wstyd                     2
# być                       2
# dalej                     2
# błąd                      2
# przyjaciele               1
# tworzył                   1
# grekiem                   1
# was                       1
# nieporozumieniem          1
# testuje                   1
# paranoja                  1
# inaczej                   1
# warmię                    1
# podpis                    1
# czytelnika                1
# zupa                      1

# %%
# check the items following individual punctuation marks
res_dict = {}
for punct_symb in target_classes:
    display(Markdown(f'#### Punctuation mark: "{punct_symb}"'))
    df = punctuations_df.loc[punctuations_df["item"] == punct_symb].reset_index()
    display(pd.DataFrame(df["next_item"].value_counts()).head(20))
# Out:
# #### Punctuation mark: ","
#         next_item
# że           1356
# a             575
# w             317
# ale           245
# który         240
# które         224
# która         160
# to            160
# co            120
# jak           118
# bo            107
# by             99
# na             92
# aby            92
# którzy         87
# czy            87
# nie            82
# gdzie          80
# z              79
# iż             65
# #### Punctuation mark: "."
#          next_item
# w              700
# na             203
# in             139
# nie            120
# po             115
# to             115
# z              113
# do             109
# według          87
# jak             77
# o               70
# a               69
# od              59
# jest            58
# czy             55
# podczas         42
# jednak          42
# co              42
# pl              42
# i               42
# #### Punctuation mark: "-"
#               next_item
# powiedział          117
# w                    38
# stwierdził           32
# mówił                28
# dodał                26
# poinformował         24
# to                   21
# nie                  21
# letni                19
# u                    18
# jak                  16
# mówi                 16
# napisał              16
# 3                    15
# i                    14
# 1                    14
# na                   13
# a                    13
# 19                   12
# jest                 12
# #### Punctuation mark: ":"
#         next_item
# 00             59
# 30             20
# w              19
# zgłoś          19
# 1              18
# 2              10
# 0               9
# polska          7
# 3               7
# nie             7
# 24              6
# 25              6
# 15              6
# wiki            6
# to              6
# z               5
# 04              5
# jest            5
# 20              5
# 39              4
# #### Punctuation mark: "?"
#           next_item
# czy              31
# w                28
# to               23
# nie              22
# a                19
# bo               12
# z                10
# przecież         10
# na               10
# tak              10
# dlaczego         10
# jak               9
# no                9
# jeśli             9
# co                9
# chyba             8
# i                 8
# zgłasza           7
# może              6
# ja                6
# #### Punctuation mark: "!"
#              next_item
# w                    6
# co                   5
# .                    4
# należy               4
# ,                    3
# do                   3
# jak                  2
# ja                   2
# to                   2
# nie                  2
# czy                  2
# ks                   1
# jestem               1
# spolecznosc          1
# koniecznym           1
# można                1
# błędy                1
# nasze                1
# moim                 1
# znalazłem            1

# %%
# Conclusions:
# 1. there is a need to handle abbreviations within the baseline model
# 2. data cleaning seems to be ok
# 3. certainty: abbreviations for dots, two-part expressions for dashes,
