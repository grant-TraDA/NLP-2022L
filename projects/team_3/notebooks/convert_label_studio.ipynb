# %%
import json

from tool.annotations_utils import read_annotations, has_intersection

# Set title
TITLE = 'Nad_Niemnem'
DIR_PATH = f'..\\experiments\\polish'

# %%
# useful for label studio setup
def create_choices_for_label_studio(filepath):
    choices = []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file.readlines():
            choices.append(f'<Choice value="{line.strip()}"/>')
    return ' '.join(choices)


create_choices_for_label_studio(f'..\\data\\lists_of_characters\\{TITLE}')
# Out:
# '<Choice value="Justyna Orzelska"/> <Choice value="Jan Bohatyrowicz"/> <Choice value="Benedykt Korczyński"/> <Choice value="Anzelm Bohatyrowicz"/> <Choice value="Witold Korczyński"/> <Choice value="Marta Korczyńska"/> <Choice value="Emilia Korczyńska"/> <Choice value="Zygmunt Korczyński"/> <Choice value="Teofil Różyc"/> <Choice value="Andrzejowa Korczyńska"/> <Choice value="Klotylda Korczyńska"/> <Choice value="Bolesław Kirło"/> <Choice value="Maria Kirłowa"/> <Choice value="Jadwiga Domuntówna"/> <Choice value="Teresa Plińska"/> <Choice value="Bohatyrowiczowie"/>'

# %%
def prepare_single_annotation(annotation_id, annotation_content):
    return {'id': annotation_id + 1,
            'data': {'text': annotation_content},
            'annotations': [
                {'model_version': 'v1', 'result': []}]}


def convert_to_label_studio_entity(entity, annotation, version=0):
    if version == 0:
        return {
                    'from_name': 'label',
                    'to_name': 'text',
                    'type': 'labels',
                    'id': str(hash(str(annotation)+str(entity))),
                    'value': {
                        'start': entity[0],
                        'end': entity[1],
                        'text': annotation['content'][entity[0]:entity[1]],
                        'labels': ['PERSON']
                    }
                }
    if version == 1:
        return {
                    'value': {
                        'start': entity[0],
                        'end': entity[1],
                        'text': annotation['content'][entity[0]:entity[1]],
                        'choices': [entity[2]]
                    },
                    'id': str(hash(str(annotation)+str(entity))),
                    'from_name': 'relevance',
                    'to_name': 'text',
                    'type': 'choices'
            }


def convert_to_label_studio_format(raw_annotations, output_path=None):
    new_annotations = []

    for anno_id, anno in enumerate(raw_annotations):
        single_annotation = prepare_single_annotation(anno_id, anno['content'])

        for entity in anno['entities']:
            new_entity_v0 = convert_to_label_studio_entity(entity, anno, 0)
            new_entity_v1 = convert_to_label_studio_entity(entity, anno, 1)

            single_annotation['annotations'][0]['result'].append(new_entity_v0)
            single_annotation['annotations'][0]['result'].append(new_entity_v1)

        new_annotations.append(single_annotation)

    if output_path:
        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(json.dumps(new_annotations).encode('utf8').decode())
    return new_annotations

# %%
annotations = read_annotations(f'{DIR_PATH}\\{TITLE}.json')

# import this file to label studio
convert_to_label_studio_format(
    annotations,
    f'..\\data\\labelstudio_annotations\\labelstudio_input\\{TITLE}.json')
# Out:
# [{'id': 1,
#   'data': {'text': 'Pani Emilia z niezwykłą u niej żywością poruszyła się na szezlongu i wołać zaczęła:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '1670179494280263763',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '1670179494280263763',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 2,
#   'data': {'text': '— Panie Bolesławie! Proszę Tereni nie dokuczać! Niech pan jej nie dręczy! Ją dziś zęby bolą.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-5943501247716871648',
#       'value': {'start': 8,
#        'end': 18,
#        'text': 'Bolesławie',
#        'labels': ['PERSON']}},
#      {'value': {'start': 8,
#        'end': 18,
#        'text': 'Bolesławie',
#        'choices': ['Bolesław Kirło']},
#       'id': '-5943501247716871648',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6239844271003900425',
#       'value': {'start': 27,
#        'end': 33,
#        'text': 'Tereni',
#        'labels': ['PERSON']}},
#      {'value': {'start': 27,
#        'end': 33,
#        'text': 'Tereni',
#        'choices': ['PERSON']},
#       'id': '-6239844271003900425',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 3,
#   'data': {'text': 'Kirło wyprostował się.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '4935394290881671560',
#       'value': {'start': 0, 'end': 5, 'text': 'Kirło', 'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 5,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '4935394290881671560',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 4,
#   'data': {'text': '— Racja — wyrzekł z powagą — racja!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 5,
#   'data': {'text': 'Buziak kobiety, którą zęby bolą, pożądanym nie jest, chociażby człowiek… kiedy indziej sobie na niego i bardzo zęby zaostrzył.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 6,
#   'data': {'text': 'No, cóż mam robić?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 7,
#   'data': {'text': 'Widzę, że muszę ciekawość pań darmo już zaspokoić.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 8,
#   'data': {'text': 'Taki to los biednego człowieka na tym świecie!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 9,
#   'data': {'text': 'Żadnej za nic nagrody! Ale nie! — zawołał nagle i z komiczną desperacją zwracając się do pani domu — chyba pani choć w rączkę pocałować się pozwoli!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 10,
#   'data': {'text': '— Dobrze, dobrze — śmiejąc się i podając mu rękę wołała pani Emilia — tylko niech pan już mówi…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-5662071410894399371',
#       'value': {'start': 61,
#        'end': 67,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 61,
#        'end': 67,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '-5662071410894399371',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 11,
#   'data': {'text': 'Rączkę sobie podaną, istotnie śliczną, położył na swej dużej, kościstej dłoni i z miną smakosza przyglądał się jej chwilę swymi błyszczącymi, świdrującymi oczkami.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 12,
#   'data': {'text': '— Śliczna! Miła! Malusia! Malusienieczka rączka! — wymówił i złożył na niej długi pocałunek, w którym cześć i galanteria mieszały się z tajonym, niejako połykanym lubowaniem się przyjemnością innego wcale rzędu.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 13,
#   'data': {'text': 'Cień bladego rumieńca przepłynął chude policzki pani Emilii; cofnęła rękę i z większym jeszcze ożywieniem, z błyskiem w oczach, upomniała się o imię i nazwisko gracji.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-7049015272376820475',
#       'value': {'start': 53,
#        'end': 59,
#        'text': 'Emilii',
#        'labels': ['PERSON']}},
#      {'value': {'start': 53,
#        'end': 59,
#        'text': 'Emilii',
#        'choices': ['Emilia Korczyńska']},
#       'id': '-7049015272376820475',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 14,
#   'data': {'text': '— Była to — wzdychając i wydymając wargi zadeklamował Kirło — była to cioteczna siostrzenica pana Benedykta Korczyńskiego, panna Justyna Orzelska.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-3705089619959106045',
#       'value': {'start': 54,
#        'end': 59,
#        'text': 'Kirło',
#        'labels': ['PERSON']}},
#      {'value': {'start': 54,
#        'end': 59,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '-3705089619959106045',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6696853504312242512',
#       'value': {'start': 98,
#        'end': 121,
#        'text': 'Benedykta Korczyńskiego',
#        'labels': ['PERSON']}},
#      {'value': {'start': 98,
#        'end': 121,
#        'text': 'Benedykta Korczyńskiego',
#        'choices': ['Benedykt Korczyński']},
#       'id': '6696853504312242512',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6189735918810067022',
#       'value': {'start': 129,
#        'end': 145,
#        'text': 'Justyna Orzelska',
#        'labels': ['PERSON']}},
#      {'value': {'start': 129,
#        'end': 145,
#        'text': 'Justyna Orzelska',
#        'choices': ['Justyna Orzelska']},
#       'id': '6189735918810067022',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 15,
#   'data': {'text': 'Dwa cienkie wykrzyki kobiece oznajmieniu temu odpowiedziały.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 16,
#   'data': {'text': 'Ale wmieszał się w nie i głos męski, który przemówił: — Więc ta panna, którąśmy jadąc spotkali, mieszka tu… jest kuzynką państwa…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 17,
#   'data': {'text': 'Pani Emilia dłoń przyłożyła do czoła; może w tej chwili uczuła ból głowy, ale grzeczna i słodka zawsze, gościowi odpowiedzieć pośpieszyła: — Tak.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8314838555571683902',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '8314838555571683902',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 18,
#   'data': {'text': 'Justysia jest krewną męża mego, córką jego ciotecznej siostry.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '2465309871349299559',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'Justysia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 8,
#        'text': 'Justysia',
#        'choices': ['Justyna Orzelska']},
#       'id': '2465309871349299559',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 19,
#   'data': {'text': 'Ojciec jej, pan Orzelski, przez nieszczęśliwe zdarzenia utracił swój majątek, a wkrótce potem owdowiał.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-8722322151873983155',
#       'value': {'start': 16,
#        'end': 24,
#        'text': 'Orzelski',
#        'labels': ['PERSON']}},
#      {'value': {'start': 16,
#        'end': 24,
#        'text': 'Orzelski',
#        'choices': ['Justyna Orzelska']},
#       'id': '-8722322151873983155',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 20,
#   'data': {'text': 'Od tego czasu oboje u nas mieszkają.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 21,
#   'data': {'text': 'Justynka, kiedy przybyła do nas, miała lat czternaście, a w tym wieku już są przyzwyczajenia, skłonności, którymi pokierować trudno…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3206669710568538256',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'Justynka',
#        'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 8,
#        'text': 'Justynka',
#        'choices': ['Justyna Orzelska']},
#       'id': '3206669710568538256',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 22,
#   'data': {'text': 'Jest ona zresztą dobra, bardzo dobra, tylko oryginalna, ale to tak oryginalna, że nie wiem już, doprawdy, skąd jej się to wziąć mogło…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 23,
#   'data': {'text': 'Zawsze inaczej robi niż wszyscy.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 24,
#   'data': {'text': 'Wykwintny mężczyzna, którego binokle połyskiwały w cieniu, wymówił: — Piękna panna.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 25,
#   'data': {'text': 'A po krótkiej chwili dodał: — Jest w jej powierzchowności jakaś świeżość, siła, prostota…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 26,
#   'data': {'text': '— O! — zawołał Kirło — widzi pani, jak dobrze się przypatrzył…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '7882895392319963472',
#       'value': {'start': 15,
#        'end': 20,
#        'text': 'Kirło',
#        'labels': ['PERSON']}},
#      {'value': {'start': 15,
#        'end': 20,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '7882895392319963472',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 27,
#   'data': {'text': 'a raz tylko i to śród drogi cukierek ten widział…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 28,
#   'data': {'text': 'Kobieta z obwiązaną twarzą wtrąciła: — Justynka ma śliczną figurę…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '5160861091661118996',
#       'value': {'start': 39,
#        'end': 47,
#        'text': 'Justynka',
#        'labels': ['PERSON']}},
#      {'value': {'start': 39,
#        'end': 47,
#        'text': 'Justynka',
#        'choices': ['Justyna Orzelska']},
#       'id': '5160861091661118996',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 29,
#   'data': {'text': 'Ja zawsze figury jej zazdroszczę…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 30,
#   'data': {'text': 'Błyszczące binokle szybko zwróciły się ku niej.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 31,
#   'data': {'text': '— Pani mówi? — cedząc nieco wyrazy zapytał gość.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 32,
#   'data': {'text': 'Może pani Emilia uczuła niewłaściwość odezwania się swej towarzyszki, bo szybko wtrąciła:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6790261306984971784',
#       'value': {'start': 10,
#        'end': 16,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 10,
#        'end': 16,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '6790261306984971784',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 33,
#   'data': {'text': '— Tereniu, nie przedstawiłam ci jeszcze nowego sąsiada naszego…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 34,
#   'data': {'text': 'Gdy był u nas po raz pierwszy, leżałaś na migrenę czy flukcję…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 35,
#   'data': {'text': 'Pan Teofil Różyc, panna Teresa Plińska, towarzyszka moja, niegdyś nauczycielka mojej córki, gdy była ona malutka…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-594631244508327787',
#       'value': {'start': 4,
#        'end': 16,
#        'text': 'Teofil Różyc',
#        'labels': ['PERSON']}},
#      {'value': {'start': 4,
#        'end': 16,
#        'text': 'Teofil Różyc',
#        'choices': ['Teofil Różyc']},
#       'id': '-594631244508327787',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8030530935888263262',
#       'value': {'start': 24,
#        'end': 38,
#        'text': 'Teresa Plińska',
#        'labels': ['PERSON']}},
#      {'value': {'start': 24,
#        'end': 38,
#        'text': 'Teresa Plińska',
#        'choices': ['Teresa Plińska']},
#       'id': '8030530935888263262',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 36,
#   'data': {'text': 'Wszakże to drugi raz dopiero mam przyjemność widzieć pana w domu naszym?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 37,
#   'data': {'text': '— Tak, pani — z wytwornym ukłonem odpowiedział zapytany — i winszuję sobie, żem w tej pustej okolicy znalazł dom taki jak państwa.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 38,
#   'data': {'text': 'Zawdzięczam to panu Kirle, który mnie pod tym względem oświecił…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6902522656001950964',
#       'value': {'start': 20,
#        'end': 25,
#        'text': 'Kirle',
#        'labels': ['PERSON']}},
#      {'value': {'start': 20,
#        'end': 25,
#        'text': 'Kirle',
#        'choices': ['PERSON']},
#       'id': '6902522656001950964',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 39,
#   'data': {'text': '— Pan Kirło jest w każdym wypadku najlepszym sąsiadem i przyjacielem naszym.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-133541070577089326',
#       'value': {'start': 6, 'end': 11, 'text': 'Kirło', 'labels': ['PERSON']}},
#      {'value': {'start': 6,
#        'end': 11,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '-133541070577089326',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 40,
#   'data': {'text': '— Ja, pani, jestem zawsze najlepszym z ludzi i tylko… zapoznanym.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 41,
#   'data': {'text': '— W domu naszym przynajmniej znajdujesz pan najzupełniejsze uznanie…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 42,
#   'data': {'text': 'Kirło ukłonił się z galanterią i wdzięcznością, ale dodał: — Nie u wszystkich, niestety, mieszkańców tego domu…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-439786670318471747',
#       'value': {'start': 0, 'end': 5, 'text': 'Kirło', 'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 5,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '-439786670318471747',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 43,
#   'data': {'text': '— Ależ nie! U wszystkich! Któż by?…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 44,
#   'data': {'text': '— Panna Marta, na przykład, nie uznaje mię…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-2536604034394067157',
#       'value': {'start': 8, 'end': 13, 'text': 'Marta', 'labels': ['PERSON']}},
#      {'value': {'start': 8,
#        'end': 13,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '-2536604034394067157',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 45,
#   'data': {'text': '— z komiczną żałością skarżył się Kirło.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3635329626590610214',
#       'value': {'start': 34,
#        'end': 39,
#        'text': 'Kirło',
#        'labels': ['PERSON']}},
#      {'value': {'start': 34,
#        'end': 39,
#        'text': 'Kirło',
#        'choices': ['Bolesław Kirło']},
#       'id': '3635329626590610214',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 46,
#   'data': {'text': '— O, Marta… Ona taka biedna… zgorzkniała… popędliwa…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-4319756299924343779',
#       'value': {'start': 5, 'end': 10, 'text': 'Marta', 'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 10,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '-4319756299924343779',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 47,
#   'data': {'text': '— Panna Justyna…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-4269208866440139952',
#       'value': {'start': 8,
#        'end': 15,
#        'text': 'Justyna',
#        'labels': ['PERSON']}},
#      {'value': {'start': 8,
#        'end': 15,
#        'text': 'Justyna',
#        'choices': ['Justyna Orzelska']},
#       'id': '-4269208866440139952',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 48,
#   'data': {'text': '— O Justynka! Ona tak jest oryginalna…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '1440191303392763435',
#       'value': {'start': 4,
#        'end': 12,
#        'text': 'Justynka',
#        'labels': ['PERSON']}},
#      {'value': {'start': 4,
#        'end': 12,
#        'text': 'Justynka',
#        'choices': ['Justyna Orzelska']},
#       'id': '1440191303392763435',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 49,
#   'data': {'text': '— Mąż pani…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 50,
#   'data': {'text': '— Mąż mój! On zajęty… nietowarzyski… zawsze tylko o gospodarstwie swoim i o interesach…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-7726179476648612893',
#       'value': {'start': 22,
#        'end': 35,
#        'text': 'nietowarzyski',
#        'labels': ['PERSON']}},
#      {'value': {'start': 22,
#        'end': 35,
#        'text': 'nietowarzyski',
#        'choices': ['PERSON']},
#       'id': '-7726179476648612893',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 51,
#   'data': {'text': 'Przerwała i zwróciła się do Teresy Plińskiej, która w tej chwili z zachwyceniem przypatrywała się błyszczącym binoklom w cieniu siedzącego gościa.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-2180980372984652556',
#       'value': {'start': 28,
#        'end': 44,
#        'text': 'Teresy Plińskiej',
#        'labels': ['PERSON']}},
#      {'value': {'start': 28,
#        'end': 44,
#        'text': 'Teresy Plińskiej',
#        'choices': ['Teresa Plińska']},
#       'id': '-2180980372984652556',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 52,
#   'data': {'text': '— Tereniu, daj mi trochę wody i proszek bromowy, bo czuję nadchodzący globus.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6067996091664298360',
#       'value': {'start': 2,
#        'end': 9,
#        'text': 'Tereniu',
#        'labels': ['PERSON']}},
#      {'value': {'start': 2,
#        'end': 9,
#        'text': 'Tereniu',
#        'choices': ['PERSON']},
#       'id': '-6067996091664298360',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 53,
#   'data': {'text': 'Teresa poskoczyła ku toalecie i w mgnieniu oka podała towarzyszce żądane przedmioty.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3570130545634828050',
#       'value': {'start': 0, 'end': 6, 'text': 'Teresa', 'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 6,
#        'text': 'Teresa',
#        'choices': ['Teresa Plińska']},
#       'id': '3570130545634828050',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 54,
#   'data': {'text': 'Pani Emilia delikatnie, z wdziękiem ujęła jedną ręką kryształową szklankę, drugą proszek zamknięty w dwu okrągłych opłatkach i tłumacząc się jakby z czynności, której dokonać miała, do nowego sąsiada rzekła:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-2682849250729748586',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '-2682849250729748586',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 55,
#   'data': {'text': '— Globus histericus… dokucza mi bardzo… szczególniej kiedy się czymś wzruszę… zmartwię…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 56,
#   'data': {'text': 'Tu połknęła proszek.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 57,
#   'data': {'text': 'Miała tyle powabu i gracji przy połykaniu lekarstwa, ile jej ma wyćwiczona tancerka w przybieraniu zalotnej pozy.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 58,
#   'data': {'text': 'Jednak widać było, że cierpiała naprawdę; ręką dotykała piersi i gardła, w których czuła nieznośne duszenie.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 59,
#   'data': {'text': '— Czy świeże powietrze ulgi pani nie przynosi — ze współczuciem zapytał Różyc.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8053197170733362799',
#       'value': {'start': 72,
#        'end': 77,
#        'text': 'Różyc',
#        'labels': ['PERSON']}},
#      {'value': {'start': 72,
#        'end': 77,
#        'text': 'Różyc',
#        'choices': ['Teofil Różyc']},
#       'id': '8053197170733362799',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 60,
#   'data': {'text': '— Może pani okno otworzyć rozkaże?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 61,
#   'data': {'text': '— O, nie, nie! — z żywym przeczeniem zawołała cierpiąca kobieta.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 62,
#   'data': {'text': '— Ja się tak lękam wiatru, ciągów, słońca… Od wiatru dostaję zawrotu głowy, od ciągów newralgii, od słońca migreny… Tereniu, podaj mi, proszę cię, toaletowy ocet…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 63,
#   'data': {'text': 'Kirło, cały nad nią schylony, z czułością szeptał: — Cóż, czy lepiej trochę?… dusi ciągle?… może przechodzi?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 64,
#   'data': {'text': 'Teresa podając ocet schyliła się też nad towarzyszką:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3207979398022032350',
#       'value': {'start': 0, 'end': 6, 'text': 'Teresa', 'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 6,
#        'text': 'Teresa',
#        'choices': ['Teresa Plińska']},
#       'id': '3207979398022032350',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 65,
#   'data': {'text': '— Początek migreny? Prawda? Mój Boże!'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-1719301491635694988',
#       'value': {'start': 32, 'end': 36, 'text': 'Boże', 'labels': ['PERSON']}},
#      {'value': {'start': 32,
#        'end': 36,
#        'text': 'Boże',
#        'choices': ['Bolesław Kirło']},
#       'id': '-1719301491635694988',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 66,
#   'data': {'text': 'I mnie także zaczyna głowa boleć…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 67,
#   'data': {'text': 'Pani Emilia nacierając skronie octem cichutko szepnęła:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-9124628319887490283',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '-9124628319887490283',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 68,
#   'data': {'text': '— Moja Tereniu, ta Marta nie wraca dotąd z kościoła…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8258078432184361225',
#       'value': {'start': 19,
#        'end': 24,
#        'text': 'Marta',
#        'labels': ['PERSON']}},
#      {'value': {'start': 19,
#        'end': 24,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '8258078432184361225',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 69,
#   'data': {'text': 'jestem niespokojna o obiad…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 70,
#   'data': {'text': 'idź, dowiedz się, czy nakrywają do stołu.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 71,
#   'data': {'text': 'Czemu ta Marta nie wraca?…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '1811433907370796118',
#       'value': {'start': 9, 'end': 14, 'text': 'Marta', 'labels': ['PERSON']}},
#      {'value': {'start': 9,
#        'end': 14,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '1811433907370796118',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 72,
#   'data': {'text': 'Nie wiem, czy gotują już dla mnie rosół…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 73,
#   'data': {'text': 'czuję, że nic innego dziś jeść nie będę mogła…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 74,
#   'data': {'text': 'Ach, ta Marta nie wraca…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6871461292031991138',
#       'value': {'start': 8, 'end': 13, 'text': 'Marta', 'labels': ['PERSON']}},
#      {'value': {'start': 8,
#        'end': 13,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '6871461292031991138',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 75,
#   'data': {'text': 'Benedykt skończył szkołę agronomiczną i do swego Korczyna wrócił w roku 1861.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-8576002707856664363',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'Benedykt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 8,
#        'text': 'Benedykt',
#        'choices': ['Benedykt Korczyński']},
#       'id': '-8576002707856664363',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 76,
#   'data': {'text': 'Matki nie miał już od dawna; ojciec mu zmarł przed paru laty; siostra była zamężna.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '2134612432338404764',
#       'value': {'start': 0, 'end': 5, 'text': 'Matki', 'labels': ['PERSON']}},
#      {'value': {'start': 0, 'end': 5, 'text': 'Matki', 'choices': ['PERSON']},
#       'id': '2134612432338404764',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 77,
#   'data': {'text': 'W zamian mniej niż o dwie mile od Korczyna, na pięknym folwarku swym gospodarował od lat kilku już ożeniony, starszy brat jego, Andrzej; a młodszy, po skończeniu uniwersyteckiego kursu, tylko co wrócił do rodzinnego domu z zamiarem użycia w nim niedługiego odpoczynku.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-3745016049190263312',
#       'value': {'start': 128,
#        'end': 135,
#        'text': 'Andrzej',
#        'labels': ['PERSON']}},
#      {'value': {'start': 128,
#        'end': 135,
#        'text': 'Andrzej',
#        'choices': ['Andrzejowa Korczyńska']},
#       'id': '-3745016049190263312',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 78,
#   'data': {'text': 'Oprócz tego znalazł w domu krewną swoją, od dzieciństwa sierotę i przez rodziców jego wychowaną, Martę Korczyńską.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3352693848051747557',
#       'value': {'start': 97,
#        'end': 113,
#        'text': 'Martę Korczyńską',
#        'labels': ['PERSON']}},
#      {'value': {'start': 97,
#        'end': 113,
#        'text': 'Martę Korczyńską',
#        'choices': ['Marta Korczyńska']},
#       'id': '3352693848051747557',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 79,
#   'data': {'text': 'Miała ona podówczas lat dwadzieścia cztery i w pełnym znaczeniu tego wyrazu można było stosować do niej nazwę dziewoi.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 80,
#   'data': {'text': 'Zanadto może wysoka, ale kształtna i ruchliwa, ognistooka, wesoła i wiecznie czynna, tak mu dom napełniała krzątaniem się swym, ładem i dostatkiem, że opustoszenia jego prawie nie uczuł.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 81,
#   'data': {'text': 'Zresztą trzej bracia byli ze sobą zawsze w przyjaźni i zgodzie, a teraz do życia ich wpłynął pierwiastek, który z nich uczynił trzy niby strzały równym pędem ku jednemu celowi lecące.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 82,
#   'data': {'text': 'We wszystkich trzech ozwała się naraz krew żołnierzy spod Baru i Samosierry, to zaś, co w pokoleniu najbliższym zadrzemało było i tylko przez sen niekiedy płakało, w nich uderzone dzwonem czasu krzyknęło i na skrzydłach fantazji wleciało w wysoko gorejący płomień.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 83,
#   'data': {'text': 'Hej! Gorączką i burzą przeleciały im te dwa lata!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 84,
#   'data': {'text': 'Stojące wody społeczne zaszumiały, wzdęły się i wyrzucały w górę kipiące kaskady; w martwej atmosferze wichry zaśpiewały roznosząc po ziemi złote tumany, a na niebie malując jutrzenki i tęcze.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 85,
#   'data': {'text': 'Duch demokratyzmu równającym pługiem orał społeczną glebę.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 86,
#   'data': {'text': 'Wyżyny, skruchą zdjęte, pochylały się ku nizinom, gotowe do wynagrodzenia krzywd, żebrzące prawie o życzliwość i ufność.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 87,
#   'data': {'text': 'Przyjazne i poufałe stosunki zapanowały były wtedy pomiędzy Korczynem a wsią sąsiednią, noszącą nazwę Bohatyrowicze.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 88,
#   'data': {'text': 'Mieszkańcy tej wsi mieli kiedyś pergaminy i przywileje szlacheckie, ale przez zbieg okoliczności różnych utracili je od dość dawna i wiedli znojne, ciasne, ubogie życia małych rolników.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 89,
#   'data': {'text': 'Nagle dom korczyński na oścież roztworzył się przed nimi. Hej!'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '3645717257315362123',
#       'value': {'start': 10,
#        'end': 20,
#        'text': 'korczyński',
#        'labels': ['PERSON']}},
#      {'value': {'start': 10,
#        'end': 20,
#        'text': 'korczyński',
#        'choices': ['Benedykt Korczyński']},
#       'id': '3645717257315362123',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 90,
#   'data': {'text': 'Byłoż tam wtedy, było ruchu i tłumu w tym niskim, obszernym domu!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 91,
#   'data': {'text': '— Takem się zmęczył, moja Emilciu — zaczął — że już trochę odpocząć muszę.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8146573504814694740',
#       'value': {'start': 26,
#        'end': 33,
#        'text': 'Emilciu',
#        'labels': ['PERSON']}},
#      {'value': {'start': 26,
#        'end': 33,
#        'text': 'Emilciu',
#        'choices': ['Emilia Korczyńska']},
#       'id': '8146573504814694740',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 92,
#   'data': {'text': 'Niech tam sobie ekonom i robotnicy poczekają, a ja kwadransik przy tobie posiedzę…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 93,
#   'data': {'text': 'Uf! Te żniwa!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 94,
#   'data': {'text': 'Nim je człowiek przebędzie, sto upałów go spali i sto strachów po nim przejdzie…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 95,
#   'data': {'text': '— Ja także — z cicha odparła kobieta — czuję się bardzo zmęczona upałem.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 96,
#   'data': {'text': '— Ale co tam ten upał!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 97,
#   'data': {'text': '— ręką po spoconym czole przesuwając ciągnął Benedykt — fizyczną przykrość każdy znieść może, jeśli jest przy tym spokój…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-7892031343926983032',
#       'value': {'start': 45,
#        'end': 53,
#        'text': 'Benedykt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 45,
#        'end': 53,
#        'text': 'Benedykt',
#        'choices': ['Benedykt Korczyński']},
#       'id': '-7892031343926983032',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 98,
#   'data': {'text': '— A cóż cię znowu tak bardzo niepokoić może?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 99,
#   'data': {'text': '— z ledwie dosłyszalną ironią zapytała żona.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 100,
#   'data': {'text': '— Hm! Zawsze mnie o to pytasz, zawsze ci wszystko opowiadam i zawsze pytasz znowu…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 101,
#   'data': {'text': '— Tak niezdolna jestem do zrozumienia i zapamiętania wszystkich twoich kłopotów i interesów…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 102,
#   'data': {'text': 'Z większym niż przedtem znużeniem przechyliła się na poręcz ławki i wygodniej drobne swe stopy na podnóżku ułożyła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 103,
#   'data': {'text': '— Jednakże — z trochą irytacji w głosie zaczął znowu Benedykt — rzeczy te są bardzo zrozumiałe i do zapamiętania łatwe…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8191349624566030343',
#       'value': {'start': 53,
#        'end': 61,
#        'text': 'Benedykt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 53,
#        'end': 61,
#        'text': 'Benedykt',
#        'choices': ['Benedykt Korczyński']},
#       'id': '8191349624566030343',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 104,
#   'data': {'text': 'Do końca życia chyba nie zapomnę, w jakim byłem strachu, kiedy przeszłej jesieni z powodu złych zbiorów nie mogłem na czas zapłacić bankowej raty…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 105,
#   'data': {'text': 'Wszakże już Korczyn opisywać miano i ledwie nieledwie dostawszy pieniędzy, piorunem z nimi do Wilna leciałem.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 106,
#   'data': {'text': 'Całą przeszłoroczną jesień biłem się jak ryba w wodzie…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 107,
#   'data': {'text': 'Nie daj Boże takiej drugiej jesieni…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '4596326232705286713',
#       'value': {'start': 8, 'end': 12, 'text': 'Boże', 'labels': ['PERSON']}},
#      {'value': {'start': 8,
#        'end': 12,
#        'text': 'Boże',
#        'choices': ['Bolesław Kirło']},
#       'id': '4596326232705286713',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 108,
#   'data': {'text': 'Pani Emilia smutnie wstrząsnęła głową.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '195476316286649378',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '195476316286649378',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 109,
#   'data': {'text': '— Mnie także zeszłoroczna jesień wcale niewesoło przeszła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 110,
#   'data': {'text': 'Chorowałam na zapalenie oskrzeli… i sama w domu byłam… jak pustelnica…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 111,
#   'data': {'text': 'Benedykt rękę żony pocałował.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8980745435935580064',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'Benedykt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 8,
#        'text': 'Benedykt',
#        'choices': ['Benedykt Korczyński']},
#       'id': '8980745435935580064',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 112,
#   'data': {'text': '— Bieda z twoim złym zdrowiem!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 113,
#   'data': {'text': 'Prawda, że dwa miesiące prawie nie byłem w domu, a przez ten czas ty kilka dni chorowałaś obłożnie…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 114,
#   'data': {'text': 'Ale przecież sama nie byłaś!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 115,
#   'data': {'text': 'Miałaś przy sobie pannę Teresę, Martę, Justynkę, dzieci… a nawet — dodał z uśmiechem — pan Ignacy mógł cię muzyką swoją rozrywać… Jakaż to pustynia?'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '2334014644990741275',
#       'value': {'start': 24,
#        'end': 30,
#        'text': 'Teresę',
#        'labels': ['PERSON']}},
#      {'value': {'start': 24,
#        'end': 30,
#        'text': 'Teresę',
#        'choices': ['Teresa Plińska']},
#       'id': '2334014644990741275',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '364945037704452331',
#       'value': {'start': 32,
#        'end': 37,
#        'text': 'Martę',
#        'labels': ['PERSON']}},
#      {'value': {'start': 32,
#        'end': 37,
#        'text': 'Martę',
#        'choices': ['Marta Korczyńska']},
#       'id': '364945037704452331',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8566840959077212546',
#       'value': {'start': 91,
#        'end': 97,
#        'text': 'Ignacy',
#        'labels': ['PERSON']}},
#      {'value': {'start': 91,
#        'end': 97,
#        'text': 'Ignacy',
#        'choices': ['PERSON']},
#       'id': '8566840959077212546',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 116,
#   'data': {'text': '— Ja ciągle żyję na pustyni — szepnęła kobieta.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 117,
#   'data': {'text': '— Oj! — krzyknął prawie mężczyzna — bodaj, że lepiej byłoby żyć na pustyni, jak wśród okoliczności takich, z jakimi ja ciągle ubijać się muszę.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 118,
#   'data': {'text': 'Ile mnie kosztuje na przykład to ciągłe prawowanie się z chłopami!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 119,
#   'data': {'text': 'Człowiek przecież nie urodził się na tyrana i ludożercę…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 120,
#   'data': {'text': 'Kiedyś mi do tego naszego ludu serce młotem biło. Ale cóż?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 121,
#   'data': {'text': 'Ciemnota to jest, a ja na to nic nie poradzę.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6551704016278730224',
#       'value': {'start': 0,
#        'end': 8,
#        'text': 'Ciemnota',
#        'labels': ['PERSON']}},
#      {'value': {'start': 0,
#        'end': 8,
#        'text': 'Ciemnota',
#        'choices': ['PERSON']},
#       'id': '6551704016278730224',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 122,
#   'data': {'text': 'Las mi rąbią, zboże spasają, na pastwiska włażą…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 123,
#   'data': {'text': 'Czyż mogę własności swojej nie bronić?'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 124,
#   'data': {'text': 'Gdybym magnatem był, jak Boga kocham, nie dochodziłbym niczego i niechbym tam już mniej miał, byle tych sporów nie zawodzić…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-7597825036873118616',
#       'value': {'start': 25, 'end': 29, 'text': 'Boga', 'labels': ['PERSON']}},
#      {'value': {'start': 25,
#        'end': 29,
#        'text': 'Boga',
#        'choices': ['Jan Bohatyrowicz']},
#       'id': '-7597825036873118616',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 125,
#   'data': {'text': 'Ale samemu ciężko…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 126,
#   'data': {'text': 'Tu załatasz, tam dziura; tu zszyjesz, tam się rozporze — i Bóg jeszcze wie, co z nami będzie!'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '8871325176273651876',
#       'value': {'start': 59, 'end': 62, 'text': 'Bóg', 'labels': ['PERSON']}},
#      {'value': {'start': 59, 'end': 62, 'text': 'Bóg', 'choices': ['PERSON']},
#       'id': '8871325176273651876',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 127,
#   'data': {'text': 'Więc muszę, chcąc nie chcąc, włóczyć ich po sądach…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 128,
#   'data': {'text': 'a zawsze, dalibóg, we środku mi coś aż płacze!…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 129,
#   'data': {'text': 'Niżej jeszcze pochylił gruby kark, a wielkie wąsy tak mu w dół zwisły, że klap surduta prawie dotykały.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 130,
#   'data': {'text': 'Dłonie o kolana opierał i w ziemię patrzał.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 131,
#   'data': {'text': 'Pani Emilia, wzniesionym wzrokiem ścigając ruchy gałązek, z którymi wietrzyk jesienny igrał, szepnęła:'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '843126937609135695',
#       'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 11,
#        'text': 'Emilia',
#        'choices': ['Emilia Korczyńska']},
#       'id': '843126937609135695',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 132,
#   'data': {'text': '— O! I ja także wiem, co to płakać bez łez…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 133,
#   'data': {'text': 'Benedykt podniósł głowę, z uwagą jej w twarz popatrzał, ręką potem machnął i rzekł:'},
#   'annotations': [{'model_version': 'v1',
# ...
#       'value': {'start': 21,
#        'end': 28,
#        'text': 'Justyno',
#        'labels': ['PERSON']}},
#      {'value': {'start': 21,
#        'end': 28,
#        'text': 'Justyno',
#        'choices': ['Justyna Orzelska']},
#       'id': '-6441378326752452268',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 158,
#   'data': {'text': '— Duszy! — zaśmiała się przeciągle i bolesna ironia mignęła jej w oczach.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 159,
#   'data': {'text': '— Czy myślisz, że jestem takim samym dzieckiem, jakim byłam wtedy, kiedy mnie te wszystkie twoje piękne… o! takie poetyczne słowa… Nie dokończyła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 160,
#   'data': {'text': 'Nagle opanowała siebie i postąpiwszy parę kroków naprzód, rękę ku ogrodowi wyciągnęła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 161,
#   'data': {'text': '— Idź, kuzynku, i podaj ramię żonie swojej, która jest ślicznym i zapewne dobrym dzieckiem, twemu sumieniu powierzonym. Ona cię kocha… a moja dusza… Od stóp do głowy drżeć zaczęła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 162,
#   'data': {'text': '— Moja dusza — dokończyła — nie przyjmie nigdy tego, co ty jej teraz ofiarować możesz!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 163,
#   'data': {'text': 'Chwiejnym trochę, ale śpiesznym krokiem, jakby nie tylko od niego, lecz i od samej siebie uciekała, z salonu wyszła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 164,
#   'data': {'text': 'W sali jadalnej zobaczyła Martę, która nisko schylając się nad stołem i głośno sapiąc, pogrążona była w układaniu na kryształowych podstawach owoców i konfitur.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6672473099370714094',
#       'value': {'start': 26,
#        'end': 31,
#        'text': 'Martę',
#        'labels': ['PERSON']}},
#      {'value': {'start': 26,
#        'end': 31,
#        'text': 'Martę',
#        'choices': ['Marta Korczyńska']},
#       'id': '-6672473099370714094',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 165,
#   'data': {'text': 'Stanęła i patrzała chwilę na szerokie, zgarbione plecy i w tysiąc zmarszczek pogiętą twarz starej panny.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 166,
#   'data': {'text': 'Przybliżyła się prędko i dotknęła ciemnej, kościstej ręki, która z niezmierną starannością bujnym, czerwonym głogiem warstwę białych porzeczek przyozdabiała.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 167,
#   'data': {'text': '— A toż co? — głowę podnosząc krzyknęła Marta.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6020028537860703977',
#       'value': {'start': 40,
#        'end': 45,
#        'text': 'Marta',
#        'labels': ['PERSON']}},
#      {'value': {'start': 40,
#        'end': 45,
#        'text': 'Marta',
#        'choices': ['Marta Korczyńska']},
#       'id': '6020028537860703977',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 168,
#   'data': {'text': '— Czego ty chcesz ode mnie? — łagodniej zapytała.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 169,
#   'data': {'text': 'Drżąca jeszcze i ze łzami w oczach Justyna szepnęła: — Może pomóc… przynieść… cokolwiek zrobić?'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '9142490765687351160',
#       'value': {'start': 35,
#        'end': 42,
#        'text': 'Justyna',
#        'labels': ['PERSON']}},
#      {'value': {'start': 35,
#        'end': 42,
#        'text': 'Justyna',
#        'choices': ['Justyna Orzelska']},
#       'id': '9142490765687351160',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 170,
#   'data': {'text': '— Ot, jeszcze czego! Wiesz dobrze, że nie lubię, aby kto wtrącał się do moich interesów… Sama sobie zawsze radę daję i teraz dam… Baw się, kiedy ci wesoło…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 171,
#   'data': {'text': '— Mnie niewesoło… — odpowiedziała.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 172,
#   'data': {'text': '— A co ja na to poradzę? Melancholiczka jesteś!'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 173,
#   'data': {'text': 'Do głowy po rozum pójdź, chłopców bałamuć, to i wesoło będzie…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 174,
#   'data': {'text': 'W tych dwóch miesiącach Justyna pamiętała każdy dzień i prawie każde do niej i o niej wymówione słowo.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-7093626625497006713',
#       'value': {'start': 24,
#        'end': 31,
#        'text': 'Justyna',
#        'labels': ['PERSON']}},
#      {'value': {'start': 24,
#        'end': 31,
#        'text': 'Justyna',
#        'choices': ['Justyna Orzelska']},
#       'id': '-7093626625497006713',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 175,
#   'data': {'text': 'Myślała wtedy, że idzie o jej życie, więc wzrokiem i słuchem, które stały się nagle bardzo przenikliwymi, badała wszystko, co działo się wkoło niej.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 176,
#   'data': {'text': 'Wiedziała też o wszystkim. Wkoło niej wrzało.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 177,
#   'data': {'text': 'Pani Andrzejowej ubyło coś z jej majestatycznej postawy, tak czuła się zrozpaczona postanowieniem syna.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6339551857238473779',
#       'value': {'start': 5,
#        'end': 16,
#        'text': 'Andrzejowej',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 16,
#        'text': 'Andrzejowej',
#        'choices': ['Andrzejowa Korczyńska']},
#       'id': '-6339551857238473779',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 178,
#   'data': {'text': 'Mogła ona z wielką dobrocią i hojnością wychowywać ubogą sierotę, związkiem krwi połączoną z człowiekiem, którego w miarę upływającego czasu coraz więcej, jak utraconego kochanka i świętego męczennika, kochała i czciła.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 179,
#   'data': {'text': 'Ale kiedy potem tę nawet lubioną przez siebie dziewczynę przymierzała z synem swoim, znalazła ją tak malutką i położeniem w świecie, i wychowaniem, i urodą, i rozumem, że po prostu pojąć nie mogła takiego związku.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 180,
#   'data': {'text': 'O majątek mniej dbała, chociaż i pod tym względem, pomimo rzetelnego oderwania się od materialnych spraw świata i bardzo małego rozumienia majątkowych interesów, czuła, że upadające Osowce potrzebowały wzmocnienia i podpór.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '6395632078977384820',
#       'value': {'start': 182,
#        'end': 188,
#        'text': 'Osowce',
#        'labels': ['PERSON']}},
#      {'value': {'start': 182,
#        'end': 188,
#        'text': 'Osowce',
#        'choices': ['PERSON']},
#       'id': '6395632078977384820',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 181,
#   'data': {'text': 'Ale przede wszystkim pragnęła dla syna kobiety wysoko urodzonej, z rozległymi koligacjami, z wychowaniem świetnym, jakiejś na koniec muzy, która by niewątpliwemu dla niej geniuszowi jego dopomagała do wzrostu i lotu.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 182,
#   'data': {'text': 'Wszystko to, bez gniewu i uniesienia, bo z krewną Andrzeja źle obejść się nie mogła, owszem, smutnie, ale też i dumnie wypowiedziała Justynie.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '2545261767199014178',
#       'value': {'start': 50,
#        'end': 58,
#        'text': 'Andrzeja',
#        'labels': ['PERSON']}},
#      {'value': {'start': 50,
#        'end': 58,
#        'text': 'Andrzeja',
#        'choices': ['Andrzejowa Korczyńska']},
#       'id': '2545261767199014178',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '4618747394721161894',
#       'value': {'start': 133,
#        'end': 141,
#        'text': 'Justynie',
#        'labels': ['PERSON']}},
#      {'value': {'start': 133,
#        'end': 141,
#        'text': 'Justynie',
#        'choices': ['Justyna Orzelska']},
#       'id': '4618747394721161894',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 183,
#   'data': {'text': 'Daleko mniej powściągliwa była ciotka Zygmunta, kobieta bardzo żywa i wysoko ceniąca bogactwo.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-1066119892465102218',
#       'value': {'start': 38,
#        'end': 46,
#        'text': 'Zygmunta',
#        'labels': ['PERSON']}},
#      {'value': {'start': 38,
#        'end': 46,
#        'text': 'Zygmunta',
#        'choices': ['Zygmunt Korczyński']},
#       'id': '-1066119892465102218',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 184,
#   'data': {'text': '— Powinnaś była wiedzieć, moja Justynko — mawiała — że tacy ludzie jak Zygmunt z takimi jak ty dziewczętami romansują często, ale nie żenią się prawie nigdy!'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-2115123157100996530',
#       'value': {'start': 31,
#        'end': 39,
#        'text': 'Justynko',
#        'labels': ['PERSON']}},
#      {'value': {'start': 31,
#        'end': 39,
#        'text': 'Justynko',
#        'choices': ['Justyna Orzelska']},
#       'id': '-2115123157100996530',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-743530860431607649',
#       'value': {'start': 71,
#        'end': 78,
#        'text': 'Zygmunt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 71,
#        'end': 78,
#        'text': 'Zygmunt',
#        'choices': ['Zygmunt Korczyński']},
#       'id': '-743530860431607649',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 185,
#   'data': {'text': 'Na głowę pana Benedykta posypały się gromy.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '110381745768052073',
#       'value': {'start': 14,
#        'end': 23,
#        'text': 'Benedykta',
#        'labels': ['PERSON']}},
#      {'value': {'start': 14,
#        'end': 23,
#        'text': 'Benedykta',
#        'choices': ['Benedykt Korczyński']},
#       'id': '110381745768052073',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 186,
#   'data': {'text': 'Pani Andrzejowa co parę dni wzywała go do Osowiec; Darzecka przyjeżdżała sama i z szelestem jedwabnych sukien, wzburzona, głośno swe gniewy i niechęci wyrażająca, wpadała do gabinetu brata.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '4904526518428302430',
#       'value': {'start': 5,
#        'end': 15,
#        'text': 'Andrzejowa',
#        'labels': ['PERSON']}},
#      {'value': {'start': 5,
#        'end': 15,
#        'text': 'Andrzejowa',
#        'choices': ['Andrzejowa Korczyńska']},
#       'id': '4904526518428302430',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'},
#      {'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '5779220157610418686',
#       'value': {'start': 51,
#        'end': 59,
#        'text': 'Darzecka',
#        'labels': ['PERSON']}},
#      {'value': {'start': 51,
#        'end': 59,
#        'text': 'Darzecka',
#        'choices': ['PERSON']},
#       'id': '5779220157610418686',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 187,
#   'data': {'text': 'Wdał się też w sprawę i sam arystokratycznie wyglądający Darzecki, monotonną i płynną mową swą bratu żony oświadczając, że wcale nie zgadza się z jego chęciami i gustami, aby tak bliski mu przez żonę krewny żenił się — nie wiedzieć z kim…'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-3368344814367061460',
#       'value': {'start': 57,
#        'end': 65,
#        'text': 'Darzecki',
#        'labels': ['PERSON']}},
#      {'value': {'start': 57,
#        'end': 65,
#        'text': 'Darzecki',
#        'choices': ['PERSON']},
#       'id': '-3368344814367061460',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 188,
#   'data': {'text': 'Pan Benedykt wpadał w gniewy tak głośne, że w całym domu go słyszano, gdy zapytywał: „Czy ma dziewczynę utopić albo zastrzelić?”'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6284099057851956972',
#       'value': {'start': 4,
#        'end': 12,
#        'text': 'Benedykt',
#        'labels': ['PERSON']}},
#      {'value': {'start': 4,
#        'end': 12,
#        'text': 'Benedykt',
#        'choices': ['Benedykt Korczyński']},
#       'id': '-6284099057851956972',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 189,
#   'data': {'text': 'Na koniec zażądał rozmówić się o tej sprawie z Zygmuntem.'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '-6202398612264586472',
#       'value': {'start': 47,
#        'end': 56,
#        'text': 'Zygmuntem',
#        'labels': ['PERSON']}},
#      {'value': {'start': 47,
#        'end': 56,
#        'text': 'Zygmuntem',
#        'choices': ['Zygmunt Korczyński']},
#       'id': '-6202398612264586472',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 190,
#   'data': {'text': 'Rozmówił się i na zakończenie z chmurną żartobliwością rzekł: — Wiesz co, gagatku? jedź sobie znowu za granicę i ucz się malować…'},
#   'annotations': [{'model_version': 'v1', 'result': []}]},
#  {'id': 191,
#   'data': {'text': 'Osowce wprawdzie zrujnują się do reszty, ale tobie samemu serce pewno nie pęknie, bo… bo prawdę mówiąc, sam nie wiesz, czego chcesz!'},
#   'annotations': [{'model_version': 'v1',
#     'result': [{'from_name': 'label',
#       'to_name': 'text',
#       'type': 'labels',
#       'id': '7662132218708250473',
#       'value': {'start': 0, 'end': 6, 'text': 'Osowce', 'labels': ['PERSON']}},
#      {'value': {'start': 0, 'end': 6, 'text': 'Osowce', 'choices': ['PERSON']},
#       'id': '7662132218708250473',
#       'from_name': 'relevance',
#       'to_name': 'text',
#       'type': 'choices'}]}]},
#  {'id': 192,
#   'data': {'text': 'Wyjechał — a po dwóch latach spędzonych w ogniskach sztuk pięknych, przeważnie w Monachium, wrócił żonaty.'},
#   'annotations': [{'model_version': 'v1', 'result': []}]}]

# %%
def merge_annotations(anno_person, anno_hero):
    merged_annotations = []
    for p in anno_person:
        found = False

        for h in anno_hero:
            if p['start'] == h['start'] and p['end'] == h['end']:
                merged_annotations.append(
                    [p['start'], p['end'], h['choices'][0]])
                found = True
                break

        if not found:
            merged_annotations.append([p['start'], p['end'], 'PERSON'])
    return merged_annotations


def convert_from_label_studio(filepath, save_path=None):
    with open(filepath, encoding='utf-8') as f:
        data = json.loads(f.read())

    corrected_annotations = []

    min_index = min([x['id'] for x in data])
    max_index = max([x['id'] for x in data])
    for i in range(min_index, max_index + 1):
        row = [x for x in data if x['id'] == i][0]
        text = row['data']['text']
        anno_person = [a['value'] for a in row['annotations'][0]['result']
                       if a['type'] == 'labels']
        anno_hero = [a['value'] for a in row['annotations'][0]['result']
                     if a['type'] == 'choices']
        annotation = merge_annotations(anno_person, anno_hero)
        corrected_annotations.append({'content': text, 'entities': annotation})

    if save_path:
        with open(save_path, 'w') as f:
            f.write(json.dumps(corrected_annotations).encode('utf-8').decode())
    return corrected_annotations

# %%
converted_annotations = convert_from_label_studio(
    # this file is the label studio output (export)
    filepath=f'..\\data\\labelstudio_annotations\\labelstudio_output\\{TITLE}.json',
    save_path=f'..\\data\\testing_sets\\test_polish_gold_standard\\{TITLE}.json')

# original tagger annotations
pre_annotations = read_annotations(f'{DIR_PATH}\\{TITLE}.json')

# %%
gold_count = 0
pred_count = 0
exact_count = 0
wrong_hero_count = 0
intersections_count = 0
incorrect_count = 0
missing_count = 0

for gold, pred in zip(converted_annotations, pre_annotations):
    gold_entities = gold['entities']
    pred_entities = pred['entities']

    gold_count += len(gold_entities)
    pred_count += len(pred_entities)

    matched_count = 0
    for entity1 in gold_entities:
        exact = False
        intersection = False

        for entity2 in pred_entities:
            if entity1 == entity2:
                exact_count += 1
                exact = True
                matched_count += 1
                break

        if not exact:
            for entity2 in pred_entities:
                gold_content1 = gold['content'][entity1[0]:entity1[1]]
                gold_content2 = gold['content'][entity2[0]:entity2[1]]
                if entity1[:2] == entity2[:2]:
                    print('Wrong hero', entity1, entity2,
                          gold_content1, gold_content2)
                    wrong_hero_count += 1
                    matched_count += 1
                    intersection = True

                elif has_intersection(entity1, entity2):
                    print('Intersection', entity1, entity2,
                          gold_content1, gold_content2)
                    intersections_count += 1
                    intersection = True
                    matched_count += 1
                    break

        if not exact and not intersection:
            missing_count += 1

    incorrect_count += len(pred_entities) - matched_count

    assert gold_count + incorrect_count == pred_count + missing_count
    assert gold_count - exact_count - intersections_count - wrong_hero_count \
           == missing_count
# Out:
# Wrong hero [27, 33, 'Teresa Plińska'] [27, 33, 'PERSON'] Tereni Tereni
# Wrong hero [16, 24, 'PERSON'] [16, 24, 'Justyna Orzelska'] Orzelski Orzelski
# Wrong hero [20, 25, 'Bolesław Kirło'] [20, 25, 'PERSON'] Kirle Kirle
# Wrong hero [2, 9, 'Teresa Plińska'] [2, 9, 'PERSON'] Tereniu Tereniu
# Wrong hero [128, 135, 'PERSON'] [128, 135, 'Andrzejowa Korczyńska'] Andrzej Andrzej
# Wrong hero [50, 58, 'PERSON'] [50, 58, 'Andrzejowa Korczyńska'] Andrzeja Andrzeja

# %%
print('pre-annotations =', pred_count)
print('final =', gold_count)
print('corrected =', exact_count)
print('missing =', missing_count)
print('wrong hero assigned =', wrong_hero_count)
print('wrong boundaries =', intersections_count)
print('completely wrong =', incorrect_count)
# Out:
# pre-annotations = 85
# final = 80
# corrected = 69
# missing = 5
# wrong hero assigned = 6
# wrong boundaries = 0
# completely wrong = 10

# %%
counts = [TITLE.replace('_', ' '), pred_count, gold_count, exact_count,
          missing_count, wrong_hero_count, intersections_count, incorrect_count]
print(' & '.join([str(x) for x in counts]) + '\\')
# Out:
# Nad Niemnem & 85 & 80 & 69 & 5 & 6 & 0 & 10\
